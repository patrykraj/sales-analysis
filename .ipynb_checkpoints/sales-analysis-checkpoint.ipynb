# %% [markdown]
# ### 1] Importing all the libraries necessary for this project

# %%
import pandas as pd

# %% [markdown]
# ### 2] Load Data from CSV

# %%
df = pd.read_csv("data/data.csv", encoding='windows-1250')

# %%
# Head of the dataset
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ### 3] Data cleaning

# %%
# Negative price - check if double negative values
df[(df['UnitPrice']<0) & (df['Quantity']<0)]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
# No double negatives - check if incorrect price
df[df['UnitPrice']<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# Description "Adjust bad debt" -> no impact on RFM

# %%
# Check null values
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df_clean = df[(df['Quantity'] > 0) & (df['UnitPrice'] > 0) & (df['CustomerID'].notna())].copy()
df_clean
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_clean[(df_clean['Quantity']<0) & (df_clean['UnitPrice']<0)]
df_clean.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  406789.000000  406789.000000  406789.000000
# mean       12.028359       3.460811   15287.795830
# std       247.927842      69.318561    1713.573064
# min    -80995.000000       0.001000   12346.000000
# 25%         2.000000       1.250000   13954.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# Check if data has double negative values
df[(df['Quantity'] < 0) & (df['UnitPrice'] < 0)].shape
# Out:
# (0, 8)

# %% [markdown]
# No double negative values. Add revenue column with simple equation.

# %% [markdown]
# ### 3] Add revenue column

# %%
df_quantity = df['Quantity']
df_unitprice = df['UnitPrice']
df_full = df.copy()
df_full['Revenue'] = df_quantity*df_unitprice
df_full['Revenue']
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Revenue, Length: 541909, dtype: float64

# %% [markdown]
# ### 4] Fixing NaN data values

# %%
df[df_full['Quantity'] == 0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df[df_full['UnitPrice'] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df_clean['InvoiceDate'] = pd.to_datetime(df_clean['InvoiceDate'])
df_clean['CustomerID'] = df_clean['CustomerID'].astype(int)
df_clean['Country'] = df_clean['Country'].astype('category')

# %%
total_revenue = df_clean['Revenue'].sum()
total_revenue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Revenue'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ...

# %%
top_products = df_clean.groupby('Description')['Revenue'].sum().sort_values(ascending=False).head(10)
top_products

# %%
top_customers = df_clean.groupby('CustomerID')['Revenue'].sum().sort_values(ascending=False).head(10)
top_customers

# %%
df_clean.loc[:, 'InvoiceDate'] = pd.to_datetime(df_clean['InvoiceDate'])
monthly_revenue = df_clean.resample('ME', on='InvoiceDate')['Revenue'].sum()
monthly_revenue.plot(kind='line')

# %%
revenue_by_country = df_clean.groupby('Country', observed=True)['Revenue'].sum().sort_values(ascending=False)
revenue_by_country

# %%
df_full = df.copy()

# %%
returns_count = df_full[df_full['Quantity']<0]

# %%
returns_count
